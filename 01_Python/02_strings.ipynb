# %%
name = "Arif"

# %%
name
# Out:
# 'Arif'

# %%
name.upper()
# Out:
# 'ARIF'

# %%
name.endswith("if")
# Out:
# True

# %%
name.lower()
# Out:
# 'arif'

# %%
name.count("A")
# Out:
# 1

# %%
print(len(name))
# Out:
# 4

# %%
print(name.replace("Arif","Ariif"))
# Out:
# Ariif

# %%
name[0:2]
# Out:
# 'Ar'
