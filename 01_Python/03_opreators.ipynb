# %% [markdown]
# #Arthermatic operators

# %%
a = 11

# %%
b = 5

# %%
a + b
# Out:
# 16

# %%
a - b
# Out:
# 6

# %%
a * b
# Out:
# 55

# %%
a / b
# Out:
# 2.2

# %%
a % b
# Out:
# 1

# %% [markdown]
# #Comparison operators

# %%
a = 45

# %%
b = 4

# %%
a < b
# Out:
# False

# %%
a > b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %% [markdown]
# #logical operators

# %%
b1 = True
b2 = False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 or b2
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %% [markdown]
# #assignment operators

# %%
a = 45

# %%
a += 4

# %%
a
# Out:
# 49

# %%
a -= 4

# %%
a
# Out:
# 45

# %%
a * 4
# Out:
# 180

# %%
a / 4
# Out:
# 11.25

# %%
a // 4
# Out:
# 11
