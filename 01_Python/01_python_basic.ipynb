# %%
a = 5

# %%
b = 54

# %%
a + b
# Out:
# 59

# %%
name = "Arif"

# %%
print("Hello World")#This will print the hello world...
# Out:
# Hello World

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
a = "5845"

# %%
b = "8641"

# %%
int(a) + int(b)
# Out:
# 14486
