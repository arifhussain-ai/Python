# %%
name = input("Enter the name: ")
age = 23
print("My name is {} my age is {}.".format(name,age))
# Out:
# Enter the name:  Arif
# My name is Arif my age is 23.

# %%
name = input("Enter the name: ")
age = 23
print(f"My name is {name} my age is {age} year old.")
# Out:
# Enter the name:  Arif
# My name is Arif my age is 23 year old.

# %%
a = 10
b = 20
print(f"The a value is {a} and b value is {b} the total is {a+b}")
# Out:
# The a value is 10 and b value is 20 the total is 30

# %%
pi = 3.14552
print(f"The Pi value:{pi:.2f}")
# Out:
# The Pi value:3.15
