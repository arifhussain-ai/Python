# %% [raw]
# 1 Write a program to check if a number is divisible by both 3 and 5.

# %%
n = int(input("ENTER A NUM: "))

if n % 3 == 0 and n % 5 == 0:
    print("DIVIDED BY BOTH NUMBERS")
else:
    print("NOT DIVIDED BY BOTH")
# Out:
# ENTER A NUM:  3
# NOT DIVIDED BY BOTH

# %% [raw]
# 2 Find remainder without using % operator.

# %%
a = int(input("ENTER A NUMBER: "))
b = int(input("ENTER A DIVISOR: "))

reminder = a - (a // b) * b

print("REMINDER:", reminder)
# Out:
# ENTER A NUMBER:  15
# ENTER A DIVIDER:  5
# REMINDER: 0

# %% [raw]
# 3 Check equality without using ==.

# %%
a = int(input("ENTER A FIRST NUM: "))
b = int(input("ENTER A SECOND NUM: "))

if not(a>b or a<b):
    print("EQUAL")
else:
    print("NOT EQUAL")
# Out:
# ENTER A FIRST NUM:  2
# ENTER A SECOND NUM:  3
# NOT EQUAL

# %% [raw]
# 4 Evaluate:
# 3 + 4 * 2 ** 2

# %%
result = 3 + 4 * 2 ** 2

print("RESULT: ",result)
# Out:
# RESULT:  19

# %% [raw]
# 5 Check if a number lies between 10 and 50.

# %%
n = int(input("ENTER A NUM: "))

if 10<= n <=50:
    print("IN RANGE")
else:
    print("OUT OF RANGE")
# Out:
# ENTER A NUM:  45
# IN RANGE

# %% [raw]
# 6 Write a program to check if a number is divisible by 7 but not by 5.

# %%
n = int(input("ENTER A NUM: "))

if n % 7 == 0 and n % 5 != 0:
    print("VAILD NUMBER")
else:
    print("NOT VAILD NUMBER")
# Out:
# ENTER A NUM:  21
# VAILD NUMBER

# %% [raw]
# 7 Find quotient and remainder without using %.

# %%
a = int(input("ENTER A NUMBER: "))
b = int(input("ENTER A DIVISOR: "))

q = (a // b)
r = a - (q * b)

print("QUOTIENT:",q)
print("REMINDER:",r)
# Out:
# ENTER A NUMBER:  15
# ENTER A DIVISOR:  5
# QUOTIENT: 3
# REMINDER: 0

# %% [raw]
# 8 Check if a number is multiple of 2 or 3.

# %%
n = int(input("ENTER A NUMBER: "))
if n % 2 == 0 and n % 3 == 0:
    print("MULTIPLE OF 2 OR 3....")
else:
    print("NOT MULTIPLE BY BOTH 2 OR 3")
# Out:
# ENTER A NUMBER:  15
# NOT MULTIPLE BY BOTH 2 OR 3

# %% [raw]
# 9 Find largest of two numbers using operators only (no if-else).

# %%
a = int(input("ENTER A FIRST NUMBER: "))
b = int(input("ENTER A SECOND NUMBER: "))

largest = (a + b + abs(a - b)) // 2
print("LARGEST:",largest)
# Out:
# ENTER A FIRST NUMBER:  12
# ENTER A SECOND NUMBER:  5
# LARGEST: 12

# %% [raw]
# 10 Check if a number is a power of 2.

# %%
n = int(input("ENTER A NUMBER: "))

if n > 0 and (n & (n - 1)) == 0:
    print("POWER OF 2")
else:
    print("NOT POWER OF 2")
# Out:
# ENTER A NUMBER:  5
# NOT POWER OF 2

# %% [raw]
# 11 Write a program to check if a number is divisible by 2, 3, and 5.

# %%
n = int(input("ENTER A NUMBER: "))

if n % 2 == 0 and n % 3 == 0 and n % 5 == 0:
    print("NUMBER IS DIVISBLE BY ALL NUMBERS")
else:
    print("NUMBER NOT DIVISIBLE BY ALL NUMBERS")
# Out:
# ENTER A NUMBER:  30
# NUMBER IS DIVISBLE BY ALL NUMBERS

# %% [raw]
# 12 Swap two numbers without using third variable (using operators).

# %%
a = int(input("ENTER A FIRST NUMBER: "))
b = int(input("ENTER A SECOND NUMBER: "))

a,b = b,a

print(f"\nNUMBER A: {a}, NUMBER B: {b}")
# Out:
# ENTER A FIRST NUMBER:  5
# ENTER A SECOND NUMBER:  4
# NUMBER A: 4, NUMBER B: 5

# %% [raw]
# 13 Check if a number is multiple of 10.

# %%
n = int(input("ENTER A NUMBER: "))

if n % 10 == 0:
    print("MULTIPLE OF 10....")
else:
    print("NOT MULTIPLE OF 10...")
# Out:
# ENTER A NUMBER:  20
# MULTIPLE OF 10

# %% [raw]
# 14 Find absolute difference between two numbers.

# %%
a = int(input("ENTER A FIRST NUMBER: "))
b = int(input("ENTER A SECOND NUMBER: "))

diff = abs(a - b)   #abs remove the negative sign and show only postive value.

print("ABSOLUTE DIFFERENCE:",diff)
# Out:
# ENTER A FIRST NUMBER:  2
# ENTER A SECOND NUMBER:  4
# ABSOLUTE DIFFERENCE: 2

# %% [raw]
# 15 Check if a number is odd using bitwise operator.

# %%
n = int(input("ENTER A NUMBER: "))

if n & 1:
    print("ODD NUMBER")
else:
    print("EVEN NUMBER")
# Out:
# ENTER A NUMBER:  242
# EVEN NUMBER
