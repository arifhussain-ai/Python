# %%
t = (2,31,3,44,4)

# %%
len(t)
# Out:
# 5

# %%
t
# Out:
# (2, 31, 3, 44, 4)

# %%
t[0]
# Out:
# 2

# %%
person = ("Arif",23,"Engineer")
name,age,profession = person

# %%
name
# Out:
# 'Arif'

# %%
profession
# Out:
# 'Engineer'

# %%
age
# Out:
# 23

# %%
my_tuple = (3,8,34,7,5)
print(my_tuple[0])
print(my_tuple[1:3])
# Out:
# 3
# (8, 34)
