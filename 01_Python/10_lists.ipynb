# %%
l = [3,5,4,8]

# %%
l[0] = 2

# %%
l
# Out:
# [2, 5, 4, 8]

# %%
l.append(9)

# %%
l
# Out:
# [2, 5, 4, 8, 9]

# %%
l2 = [5,4]

# %%
l.extend(l2)

# %%
l
# Out:
# [2, 5, 4, 8, 9, 5, 4]

# %%
l.insert(1,899)

# %%
l
# Out:
# [2, 899, 5, 4, 8, 9, 5, 4]

# %%
number = l.pop(2)

# %%
number
# Out:
# 5

# %%
l
# Out:
# [2, 899, 4, 8, 9, 5, 4]

# %%
l.index(899)
# Out:
# 1

# %%
l.append(4)

# %%
l.count(4)
# Out:
# 3

# %%
l
# Out:
# [2, 899, 4, 8, 9, 5, 4, 4]

# %%
l.sort() #Change and sort the original list...

# %%
l
# Out:
# [2, 4, 4, 4, 5, 8, 9, 899]

# %%
l.reverse()

# %%
l
# Out:
# [899, 9, 8, 5, 4, 4, 4, 2]

# %%
newlist = [2,3,3,442,345,5,3]

# %%
sorted(newlist) #It return new sorted list not convert the original list....
# Out:
# [2, 3, 3, 3, 5, 345, 442]

# %%
newlist
# Out:
# [2, 3, 3, 442, 345, 5, 3]

# %%
y = [1,32,3,True,False,[2,4]]

# %%
y
# Out:
# [1, 32, 3, True, False, [2, 4]]

# %%
y[5]
# Out:
# [2, 4]

# %%
y[5][0]
# Out:
# 2

# %%
y[5][1]
# Out:
# 4

# %%
list1 = [4,5,4,]

# %%
list2 = [3,5,6,3]

# %%
list1 + list2 #It created a new list....
# Out:
# [4, 5, 4, 3, 5, 6, 3]

# %%
if 4 in list1:
    print("Yes...")
# Out:
# Yes...

# %%
s = "arif-salman-shahrukh"

# %%
s.split("-")
# Out:
# ['arif', 'salman', 'shahrukh']

# %%
my_lst = [] #Empty list....
