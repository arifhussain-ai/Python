# %% [markdown]
# #Taking input from users...

# %%
a = input("Enter the value of a")#By defualt it take user input as strings...
# Out:
# Enter the value of a 4

# %%
a
# Out:
# '4'

# %%
b = input("Enter the value of b")
# Out:
# Enter the value of b 5

# %%
b
# Out:
# '5'

# %%
a + b
# Out:
# '45'

# %%
int(a) + int(b)
# Out:
# 9
