# %%
f = open("14.1_filehandle.txt","r")

# %%
f.read()
# Out:
# 'Arif is a good coder....!\nSometime it make mistakes but overall okkkk......!!!!'

# %%
s = "Arif Hussain is a Programmer...!"

# %%
f.close()

# %%
f = open("14.2_FileHnadle_Arif.txt","w")

# %%
f.write(s)
# Out:
# 32

# %%
f.close()

# %%
file = open("14.1_filehandle.txt","r")
content_line1 = file.readline()
print(content_line1) #Read line one only.....!
f.close()
# Out:
# Arif is a good coder....!

# %%
line = ["Hello\n", "How are you all"]
file  = open("14.3_filehandle.txt","w")
file.writelines(line)
file.close()

# %%
file = open("14.3_filehandle.txt","a")
file.write("\nThis is a Appendlines...!")
file.close()

# %%
with open("14.3_filehandle.txt","r") as file:
    content = file.read()
    print(content)
# Out:
# Hello
# How are you all
# This is a Appendlines...!

# %%
import os

if os.path.exists("14.3_filehandle.txt"):
    print("File Found")
else:
    print("File Not Found")
# Out:
# File Found

# %%
if os.path.exists("example.txt"):
    os.remove("example.txt")
    print("file deleted..")
else:
     print("file not exists...")
# Out:
# file not exists...
