# %% [raw]
# 1 Take two numbers as input and print their sum, difference, and product.

# %%
num1 = int(input("ENTER A VAR1: "))
num2 = int(input("ENTER A VAR2: "))

print("\nSUM: ", num1+num2)
print("DIFFERENCE: ", num1+num2)
print("PRODUCT: ", num1+num2)
# Out:
# ENTER A VAR1:  4
# ENTER A VAR2:  4
# SUM:  8
# DIFFERENCE:  8
# PRODUCT:  8

# %% [raw]
# 2 Take a string input and print it in reverse.

# %%
x = "ARIF"

print("REVISIED:", x[::-1])
# Out:
# REVISIED: FIRA

# %% [raw]
# 3 Take user input and print number of characters.

# %%
s = input("ENTER A TEXT: ")

print("LENGTH OF CHARACHTERS:",len(s))
# Out:
# ENTER A TEXT:  ARIF HUSSAIN
# LENGTH OF CHARACHTERS: 12

# %% [raw]
# 4 Take a number and print its square and cube.

# %%
num = int(input("ENTER A NUM:"))

print("SQUARE:",num**2)
print("CUDE:",num*3)
# Out:
# ENTER A NUM: 2
# SQUARE: 4
# CUDE: 6

# %% [raw]
# 5 Format output like
# Name: Arif, Age: 24

# %%
name = input("ENTER A NAME:")
age = int(input("ENTER A AGE:"))

print(f"\nNAME: {name}, AGE: {age}")
# Out:
# ENTER A NAME: Arif
# ENTER A AGE: 24
# NAME: Arif, AGE: 24

# %% [raw]
# 6 Take a character as input and print its ASCII value.

# %%
ch = input("ENTER A CHARACHTER: ")

print("ASCII VALUE:", ord(ch))
# Out:
# ENTER A CHARACHTER:  a
# ASCII VALUE: 97

# %% [raw]
# 7 Take a string input and convert it to uppercase.

# %%
s = input("ENTER A STRING: ")

print("\nCONVERT UPPERCASE:", s.upper())
# Out:
# ENTER A STRING:  arif
# CONVERT UPPERCASE: ARIF

# %% [raw]
# 8 Take a string and print first and last character.

# %%
s = input("ENTER A STRING: ")

print("\nFIRST CHARACHTER:", s[0])
print("LAST CHARACHTER:", s[-1])
# Out:
# ENTER A STRING:  arif
# FIRST CHARACHTER: a
# LAST CHARACHTER: f

# %% [raw]
# 9 Take a number as input and check if it is even or odd.

# %%
n = int(input("ENTER A NUMBER: "))

if n % 2 == 0:
    print("EVEN")
else:
    print("ODD")
# Out:
# ENTER A NUMBER:  1
# ODD

# %% [raw]
# 10 Take a string input and count number of vowels.

# %%
s = input("ENTER A STRING: ")
count = 0

for ch in s.lower():
    if ch in "aeiou":
        count += 1

print("VOWELS: ",count)
# Out:
# ENTER A STRING:  arif
# VOWELS:  2
