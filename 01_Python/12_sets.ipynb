# %%
s = {2,3,4,6,77,9,77}

# %%
s
# Out:
# {2, 3, 4, 6, 9, 77}

# %%
unique_numbers = set([1,2,2,2,3,4,4,4,5,5])
print(unique_numbers)
# Out:
# {1, 2, 3, 4, 5}

# %%
s = {2,3,4,6,77,9,77}

# %%
s.add(34)

# %%
s
# Out:
# {2, 3, 4, 6, 9, 34, 77}

# %%
s.update([5,99,8,9,3455,677])

# %%
s
# Out:
# {2, 3, 4, 5, 6, 8, 9, 34, 77, 99, 677, 3455}

# %%
s.remove(3455)

# %%
s
# Out:
# {2, 3, 4, 5, 6, 8, 9, 34, 77, 99, 677}

# %%
s.discard(34)

# %%
s
# Out:
# {2, 3, 4, 5, 6, 8, 9, 77, 99, 677}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {3, 4, 5, 6, 8, 9, 77, 99, 677}

# %%
set1 = {1,2,3,4}
set2 = {4,5,6,7}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
set1.intersection(set2)
# Out:
# {4}

# %%
set1.difference(set2)
# Out:
# {1, 2, 3}

# %%
set2.difference(set1)
# Out:
# {5, 6, 7}

# %%
sub = {1,3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True

# %%
set1 & set2
# Out:
# {4}

# %%
empty_set = set()

# %%
type(empty_set)
# Out:
# set
