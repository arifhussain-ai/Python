# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
student = {
    "name" : "Arif",
    "age" : 23,
    "grade" : "A+"
}

# %%
r = student["name"]

# %%
print(r)
# Out:
# Arif

# %%
r = student.get("name2")

# %%
print(r)
# Out:
# None

# %%
student = {
    "Name" : "Arif",
    "Age" : 23,
    "Grade" : "A+"
}

# %%
student["Age"]
# Out:
# 23

# %%
print(student)
# Out:
# {'Name': 'Arif', 'Age': 23, 'Grade': 'A+'}

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'Grade'])

# %%
student.values()
# Out:
# dict_values(['Arif', 23, 'A+'])

# %%
student.items()
# Out:
# dict_items([('Name', 'Arif'), ('Age', 23), ('Grade', 'A+')])

# %%
student.update({"Profession" : "Engineering", "Collage" : "GGSESTC", "Marks" : 500})

# %%
print(student)
# Out:
# {'Name': 'Arif', 'Age': 23, 'Grade': 'A+', 'Profession': 'Engineering', 'Collage': 'GGSESTC', 'Marks': 500}

# %%
student.popitem()
# Out:
# ('Marks', 500)

# %%
print(student)
# Out:
# {'Name': 'Arif', 'Age': 23, 'Grade': 'A+', 'Profession': 'Engineering', 'Collage': 'GGSESTC'}

# %%
for key, value in student.items():
    print(key, ":", value)
# Out:
# Name : Arif
# Age : 23
# Grade : A+
# Profession : Engineering
# Collage : GGSESTC

# %%
#Printing the squareroot of number in range (1,10):-
square = {x:x**2 for x in range(1,11)}
print(square)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
