# %%
result = 10 + 2 * 3 #Multiply happen first 10 + (2 * 3)

# %%
result
# Out:
# 16

# %%
result = (10 + 2) * 3 #Parantheses first: (10 + 2) * 3

# %%
result
# Out:
# 36

# %%
result = 2**3**2 #This will goes like first: 2**(3**2) = 2**9 = 512

# %%
result
# Out:
# 512
