# %%
a = 400

# %%
if (a > 34):
    print("Greater")
else:
    print("Smaller")
# Out:
# Greater

# %%
a = int(input("Enter the value : "))
if (a > 50):
        print("Greater than 50")
elif (a > 40):
        print("Greater than 40")
elif (a > 30):
        print("Greater than 30")
else:
    print("Done....")
# Out:
# Enter the value :  65
# Greater than 50

# %%
x = 5
if (x > 5):
    print("x is greater than 5...")
else:
    print("x is not greater than 5")
# Out:
# x is not greater than 5

# %%
age = int(input("Enter a Age: "))
if (age < 18):
    category = "Minnor..."
elif (age < 60):
    category = "Adult..."
else:
    category = ("Senior Citizen...")
print("Category: ", category)
# Out:
# Enter a Age:  35
# Category:  Adult...

# %% [markdown]
# #FUNCTION WITH MULTIPLE ARGUMENTS......

# %%
def add(a,b):
    return a + b
print("Add:",add(3,4))
# Out:
# Add: 7

# %%
def min(a,b):
    return a - b
print("Minus:",min(3,2))
# Out:
# Minus: 1

# %%
def avg(a,b=10): #If we can't give any argument in b it will always take defult value of b = 10.
    return (a+b)/2

# %%
avg(4,6)
# Out:
# 5.0

# %%
avg(4)
# Out:
# 7.0

# %%
def greet(name):
    return f"Hello Good Morning....,{name}!"

# %%
print(greet("Arif"))
# Out:
# Hello Good Morning....,Arif!
