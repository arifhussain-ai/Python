# %% [raw]
# 1 Write a program to check:
#
# positive
# negative
# zero

# %%
n = int(input("ENTER A NUMBERS: "))

if n < 0:
    print("NEGATIVE NUMBER...")
elif n > 0:
    print("POSTIVE NUMBR...")
else:
    print("ZERO...")
# Out:
# ENTER A NUMBERS:  2
# POSTIVE NUMBR...

# %% [raw]
# 2 Write a program to find largest of three numbers.

# %%
a = int(input("ENTER A NUM1: "))
b = int(input("ENTER A NUM2: "))
c = int(input("ENTER A NUM3: "))

if a >= b and a >= c:
    print("LARGEST:",a)
elif b >= a and b >= c:
    print("LARGEST:",b)
else:
    print("LARGEST:",c)
# Out:
# ENTER A NUM1:  5
# ENTER A NUM2:  14
# ENTER A NUM3:  09
# LARGEST: 14

# %% [raw]
# 3 Check if a number is even or odd using ternary operator.

# %%
n = int(input("ENTER A NUMBER: "))

result = "EVEN NUMBER" if n % 2 == 0 else "ODD NUMBR"
print(result)
# Out:
# ENTER A NUMBER:  34469
# ODD NUMBR

# %% [raw]
# 4 Write a program for grading system:
#
# 90+ → A
# 70–89 → B
# <70 → C

# %%
marks = int(input("ENTER A NUMBER: "))

if marks >= 90:
    print("GRADE A")
elif marks >= 70 and n <= 89:
    print("GRADE B")
else:
    print("GRADE C")
# Out:
# ENTER A NUMBER:  98
# GRADE A

# %% [raw]
# 5 Check if a year is leap year.

# %%
year = int(input("ENTER A YEAR"))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("LEAP YEAR...")
else:
    print("NOT LEAP...")
# Out:
# ENTER A YEAR 2020
# LEAP YEAR...

# %% [raw]
# 6 Check if a number is an Armstrong number (e.g., 153 → 1³+5³+3³ = 153)

# %%
n = int(input("ENTER A NUMBER: "))
temp = n
sum = 0

while temp > 0:
    digit = temp % 10
    sum += digit ** 3
    temp //= 10

if sum == n:
    print("ARMSTRONG NUMBER")
else:
    print("NOT ARMSTRONG NUMBER")
# Out:
# ENTER A NUMBER:  153
# ARMSTRONG NUMBER

# %% [raw]
# 7 Check if a number reads same forward and backward.

# %%
n = int(input("ENTER A NUMBER: "))
temp = n
rev = 0

while temp > 0:
    digit = temp % 10
    rev = rev * 10 + digit
    temp //= 10

if rev == n:
    print("PALINDROME NUMBER...")
else:
    print("NOT PALINDROME NUMBER...")
# Out:
# ENTER A NUMBER:  121
# PALINDROME NUMBER...

# %% [raw]
# 8 Find the second largest among three numbers.

# %%
a = int(input("ENTER A NUM1: "))
b = int(input("ENTER A NUM2: "))
c = int(input("ENTER A NUM3: "))

if (a > b and a < c) or (a < b and a > c):
    print("SECOND HIGHEST NUMBER:",a)
elif(b > a and b < c) or (b < a and b > c):
    print("SECOND HIGHEST NUMBER:",b)
else:
    print("SECOND HIGHEST NUMBER:",c)
# Out:
# ENTER A NUM1:  89
# ENTER A NUM2:  94
# ENTER A NUM3:  12
# SECOND HIGHEST NUMBER: 89

# %% [raw]
# 9 Check if 3 sides can form a triangle.

# %%
a = int(input("ENTER A ANGLE 1: "))
b = int(input("ENTER A ANGLE 2: "))
c = int(input("ENTER A ANGLE 3: "))

if (a + b > c and a + c > b and b + c > a):
    print("VAILD TRIANGLE...")
else:
    print("NOT VAILD TRIANGLE...")
# Out:
# ENTER A ANGLE 1:  5
# ENTER A ANGLE 2:  4
# ENTER A ANGLE 3:  3
# VAILD TRIANGLE...

# %% [raw]
# 10 Check if triangle is:
# Equilateral
# Isosceles
# Scalene

# %%
a = int(input("ENTER A ANGLE 1: "))
b = int(input("ENTER A ANGLE 2: "))
c = int(input("ENTER A ANGLE 3: "))

if a == b == c:
    print("EQUILATERAL...")
elif a == b or b == c or a == c:
    print("ISOSCELES...")
else:
    print("SCALENE...")
# Out:
# ENTER A ANGLE 1:  4
# ENTER A ANGLE 2:  8
# ENTER A ANGLE 3:  4
# ISOSCELES...

# %% [raw]
# 11 Write a program to check:
#
# If a number is positive
# If it is even or odd
# If negative, print "Negative Number"

# %%
n = int(input("ENTER A NUMBER: "))

if n > 0:
    if n % 2 == 0:
        print("POSTIVE EVEN NUMBER")
    else:
        print("POSTIVE ODD NUMBER")
else:
    print("NEGATIVE NUMBER")
# Out:
# ENTER A NUMBER:  8
# POSTIVE EVEN NUMBER

# %% [raw]
# 12 Find the Largest number between two numbers using ternary operator.

# %%
a = int(input("ENTER A NUM1: "))
b = int(input("ENTER A NUM2: "))

largest = (a if a > b else b)

print("LARGEST NUMBER:",largest)
# Out:
# ENTER A NUM1:  4
# ENTER A NUM2:  5
# LARGEST NUMBER: 5

# %% [raw]
# 13 Check whether a student is eligible for placement.
#
# Conditions:
# Marks ≥ 60
# Attendance ≥ 75

# %%
marks = int(input("ENTER A MARKS: "))
attendance = int(input("ENTER A ATTENDANCE: "))

if marks >= 60 and attendance >= 75:
    print("ELIGIBLE FOR PLACEMENT")
else:
    print("NOT ELIGIBLE FOR PLACEMENT")
# Out:
# ENTER A MARKS:  82
# ENTER A ATTENDANCE:  90
# ELIGIBLE FOR PLACEMENT

# %% [raw]
# 14 A person can enter the club if:
#
# Age ≥ 18
# OR
# Has VIP pass

# %%
age = int(input("ENTER A AGE: "))
v_pass = input("YOU HAVE VIP PASS(YES/NO): ").lower()

if age >= 18 or v_pass == yes:
    print("ENTRY ALLOWED")
else:
    print("ENTRY NOT ALLOWED")
# Out:
# ENTER A AGE:  25
# YOU HAVE VIP PASS(YES/NO):  YES
# ENTRY ALLOWED

# %% [raw]
# 15 Create a grading system:
#
# 90+ → A
# 75–89 → B
# 50–74 → C
# Below 50 → Fail

# %%
marks = int(input("ENTER A MARKS: "))

grade = ("A" if marks >= 90 else
        "B" if marks >= 75 else
        "C" if marks >= 50 else
        "FAIL")

print("GRADE:", grade)
# Out:
# ENTER A MARKS:  99
# GRADE: A

# %% [raw]
# 16 Write a program to check whether a year is a leap year or not.
#
# Rules:
# Divisible by 400 → Leap Year
# Divisible by 100 → Not Leap Year
# Divisible by 4 → Leap Year
# Otherwise → Not Leap Year

# %%
year = int(input("ENTER A YEAR: "))

if (year % 400 == 0 or year % 4 == 0):
    print("Leap Year")
elif year % 100 != 0:
    print("Not Leap Year")
else:
    print("Not Leap Year")
# Out:
# ENTER A YEAR:  2020
# Leap Year

# %% [raw]
# 17 Find the largest number among 3 numbers using conditional operator.

# %%
a = int(input("ENTER A FIRST NUMBER: "))
b = int(input("ENTER A SECOND NUMBER: "))
c = int(input("ENTER A THIRD NUMBER: "))

largest = (a if a > b and a > c else
          b if b > c else
          c)

print("LARGEST NUMBER:",largest)
# Out:
# ENTER A FIRST NUMBER:  54
# ENTER A SECOND NUMBER:  89
# ENTER A THIRD NUMBER:  74
# LARGEST NUMBER: 89

# %% [raw]
# 18 Create a login system.
#
# Conditions:
# Username must be "admin"
# Password must be "1234"

# %%
user = input("ENTER A ADMIN: ").lower()
password = input("ENTER A PASSWORD: ")

if user == "admin" and password == "1234":
    print("LOGIN SUESSFULLY")
elif user == "admin":
    print("WRONG PASSWORD")
else:
    print("INVAILED USER")
# Out:
# ENTER A ADMIN:  aDmin
# ENTER A PASSWORD:  1234
# LOGIN SUESSFULLY

# %% [raw]
# 19 Calculate electricity bill:
#
# First 100 units → ₹5/unit
# Next 100 units → ₹7/unit
# Above 200 units → ₹10/unit

# %%
unit = int(input("ENTER A UNIT: "))

if unit <= 100:
    bill = unit * 5
elif unit <= 200:
    bill = (100 * 5) + ((unit - 100) * 7)
else:
    bill = (100 * 5 + 100 * 7) + ((unit - 200) * 10)

print("BILL GENRATED:",bill)
# Out:
# ENTER A UNIT:  250
# BILL GENRATED: 1700

# %% [raw]
# 20 Create calculator using conditions.
#
# Operations:
# +
# -
# *
# /

# %%
a = int(input("ENTER A NUM1: "))
b = int(input("ENTER A NUM2: "))

op = input("ENTER A OPERATORS(+,-,*,/): ")

if op == "+":
    print("ADDITION:",a+b)
elif op == "-":
    print("SUBTRACTION:",a-b)
elif op == "*":
    print("MULTIPLICATION:",a*b)
elif op == "/":
    if b != 0:
        print("DIVIDED:",a/b)
    else:
        print("DIVISION BY ZERO NOT ALLOWED")
else:
    print("INVAILED OPERATOR")
# Out:
# ENTER A NUM1:  5
# ENTER A NUM2:  5
# ENTER A OPERATORS(+,-,*,/):  #
# INVAILED OPERATOR

# %% [raw]
# BONUS QUESTIONS...
#
# Check whether a character is:
# Alphabet
# Digit
# Special Character

# %%
ch = input("ENTER A CHARACTER: ")

if ch.isalpha():
    print("ALPHABET")
elif ch.isdigit():
    print("NUMERIC")
else:
    print("SPECIAL CHARACTER")
# Out:
# ENTER A CHARACTER:  @
# SPECIAL CHARACTER
