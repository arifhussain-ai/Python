# %%
def https_status(code):
    match code:
        case 200:
            return "Response Ok"
        case 400:
            return "Bad Request"
        case 500:
            return "Internal Server Problem"
        case _:
            return "Unknow Error"

# %%
print(https_status(200))
# Out:
# Response Ok

# %%
point = (3,5)

# %%
match point:
    case(0,0):
        print("Origin")
    case(x,0):
        print(f"X-Axis at {x}")
    case(0,y):
        print(f"Y-Axis at {y}")
    case(x,y):
        print(f"The Point Axis at {x},{y}")
# Out:
# The Point Axis at 3,5
