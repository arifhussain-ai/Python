# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.set_theme(style ="dark")

x = np.array([1,2,3,5,8,9,20,25,32,45,50,62,69,70,74,72,80,85,90])
y = np.sin(x)

sns.lineplot(x = x, y = y)
plt.title("Beautiful Lines")
plt.show()
