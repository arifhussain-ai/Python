# %%
import matplotlib.pyplot as plt

# %%
data = [96,2,75,91,67,88,9,73,84,62,
       90,77,68,54,56,87,9,61,70,85,
       92,66,74,10,97,64,39,60,76,83,
       93,71,31,58,86,22,3,96,65,98,
       57,90,55,11,63,2,54,51,50,100]

# %%
plt.hist(data, bins=5, edgecolor = "black")
plt.xlabel("Marks",color="red")
plt.ylabel("Frequency",color="red")
plt.title("Student Marks")
plt.show()

# %%
import matplotlib.pyplot as plt

ages = [
34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
23, 48, 29, 19, 38, 17, 32, 10, 16, 31,
37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
33, 26, 23, 36, 40, 39, 21, 26, 33, 39,
25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
30, 39, 22, 26, 26, 15, 32, 32, 30, 27
]
bins = [10,20,30,40,50,60,70]

plt.hist(ages, bins=bins, edgecolor= "black")
plt.xlabel('Age Group')
plt.ylabel('Numbers Of Viewers')
plt.title('Age Distribution of YouTube Viewers')
plt.grid(True, linestyle = '--', alpha= 0.6)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ages = [
34, 28, 36, 45, 27, 27, 45, 37, 25, 35,
25, 25, 32, 10, 12, 24, 19, 33, 20, 15,
44, 27, 30, 15, 24, 31, 18, 33, 23, 27,
23, 48, 29, 19, 38, 17, 32, 10, 16, 31,
37, 31, 28, 26, 15, 22, 25, 40, 33, 12,
33, 26, 23, 36, 40, 39, 21, 26, 33, 39,
25, 28, 18, 18, 38, 43, 29, 40, 33, 23,
33, 45, 29, 45, 3, 38, 30, 27, 30, 10,
27, 33, 44, 24, 21, 24, 39, 33, 24, 35,
30, 39, 22, 26, 26, 15, 32, 32, 30, 27
]
bins = [10,20,30,40,50,60,70]

plt.hist(ages, bins=bins, edgecolor= "black")
plt.axvline(np.mean(ages), linestyle= '--', linewidth = 2, color= 'red',label = 'Average Ages')
plt.xlabel('Age Group')
plt.ylabel('Numbers Of Viewers')
plt.title('Age Distribution of YouTube Viewers')
plt.grid(True, linestyle = '--', alpha= 0.6)
plt.show()
