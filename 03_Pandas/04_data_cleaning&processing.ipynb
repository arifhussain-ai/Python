# %%
import pandas as pd

# %%
df = pd.read_csv("04.1_data_cleaning&processing.csv")

# %%
df
# Out:
#       Name   Age        City Gender              Emial   Join Date
# 0    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 1      Bob  30.0  Los Angels      M      bob@gmial.com  15-06-2020
# 2  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021
# 3    David  22.0      Mumbai      M    david@gmail.com  12-11-2019
# 4      NaN  28.0       Delhi      F      eve@gmail.com         NaN
# 5    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 6    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 7  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021
# 8  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021

# %%
df.isnull()
# Out:
#     Name    Age   City  Gender  Emial  Join Date
# 0  False  False  False   False  False      False
# 1  False  False  False   False  False      False
# 2  False   True  False   False  False      False
# 3  False  False  False   False  False      False
# 4   True  False  False   False  False       True
# 5  False  False  False   False  False      False
# 6  False  False  False   False  False      False
# 7  False   True  False   False  False      False
# 8  False   True  False   False  False      False

# %%
df.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Emial        0
# Join Date    1
# dtype: int64

# %%
df.dropna()
# Out:
#     Name   Age        City Gender            Emial   Join Date
# 0  Alice  25.0    New York      F  alice@gmail.com  01-05-2021
# 1    Bob  30.0  Los Angels      M    bob@gmial.com  15-06-2020
# 3  David  22.0      Mumbai      M  david@gmail.com  12-11-2019
# 5  Alice  25.0    New York      F  alice@gmail.com  01-05-2021
# 6  Alice  25.0    New York      F  alice@gmail.com  01-05-2021

# %%
df.dropna(axis=1)
# Out:
#          City Gender              Emial
# 0    New York      F    alice@gmail.com
# 1  Los Angels      M      bob@gmial.com
# 2       Delhi      M  charlie@gmail.com
# 3      Mumbai      M    david@gmail.com
# 4       Delhi      F      eve@gmail.com
# 5    New York      F    alice@gmail.com
# 6    New York      F    alice@gmail.com
# 7       Delhi      M  charlie@gmail.com
# 8       Delhi      M  charlie@gmail.com

# %%
df.fillna(0)
# Out:
#       Name   Age        City Gender              Emial   Join Date
# 0    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 1      Bob  30.0  Los Angels      M      bob@gmial.com  15-06-2020
# 2  Charlie   0.0       Delhi      M  charlie@gmail.com  20-07-2021
# 3    David  22.0      Mumbai      M    david@gmail.com  12-11-2019
# 4        0  28.0       Delhi      F      eve@gmail.com           0
# 5    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 6    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 7  Charlie   0.0       Delhi      M  charlie@gmail.com  20-07-2021
# 8  Charlie   0.0       Delhi      M  charlie@gmail.com  20-07-2021

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.000000
# 1    30.000000
# 2    25.833333
# 3    22.000000
# 4    28.000000
# 5    25.000000
# 6    25.000000
# 7    25.833333
# 8    25.833333
# Name: Age, dtype: float64

# %%
df.ffill()
# Out:
#       Name   Age        City Gender              Emial   Join Date
# 0    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 1      Bob  30.0  Los Angels      M      bob@gmial.com  15-06-2020
# 2  Charlie  30.0       Delhi      M  charlie@gmail.com  20-07-2021
# 3    David  22.0      Mumbai      M    david@gmail.com  12-11-2019
# 4    David  28.0       Delhi      F      eve@gmail.com  12-11-2019
# 5    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 6    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 7  Charlie  25.0       Delhi      M  charlie@gmail.com  20-07-2021
# 8  Charlie  25.0       Delhi      M  charlie@gmail.com  20-07-2021

# %%
df.bfill()
# Out:
#       Name   Age        City Gender              Emial   Join Date
# 0    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 1      Bob  30.0  Los Angels      M      bob@gmial.com  15-06-2020
# 2  Charlie  22.0       Delhi      M  charlie@gmail.com  20-07-2021
# 3    David  22.0      Mumbai      M    david@gmail.com  12-11-2019
# 4    Alice  28.0       Delhi      F      eve@gmail.com  01-05-2021
# 5    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 6    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 7  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021
# 8  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name   Age        City Gender              Emial   Join Date
# 0    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 1      Bob  30.0  Los Angels      M      bob@gmial.com  15-06-2020
# 2  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021
# 3    David  22.0      Mumbai      M    david@gmail.com  12-11-2019
# 4      NaN  28.0       Delhi      F      eve@gmail.com         NaN

# %%
df.duplicated(["Name","Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df["Name"].str.lower()
# Out:
# 0      alice
# 1        bob
# 2    charlie
# 3      david
# 4        NaN
# 5      alice
# 6      alice
# 7    charlie
# 8    charlie
# Name: Name, dtype: object

# %%
df
# Out:
#       Name   Age        City Gender              Emial   Join Date
# 0    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 1      Bob  30.0  Los Angels      M      bob@gmial.com  15-06-2020
# 2  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021
# 3    David  22.0      Mumbai      M    david@gmail.com  12-11-2019
# 4      NaN  28.0       Delhi      F      eve@gmail.com         NaN
# 5    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 6    Alice  25.0    New York      F    alice@gmail.com  01-05-2021
# 7  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021
# 8  Charlie   NaN       Delhi      M  charlie@gmail.com  20-07-2021

# %%
df["City"].str.contains("delhi", case=False)
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# Name: City, dtype: bool

# %%
type(df["City"].str.contains("delhi", case=False))
# Out:
# pandas.core.series.Series

# %%
df["City"].str.split()
# Out:
# 0      [New, York]
# 1    [Los, Angels]
# 2          [Delhi]
# 3         [Mumbai]
# 4          [Delhi]
# 5      [New, York]
# 6      [New, York]
# 7          [Delhi]
# 8          [Delhi]
# Name: City, dtype: object

# %%
type(df["City"].str.split()[0])
# Out:
# list

# %%
df2 = df.dropna().copy()

# %%
df2["Age"] = df2["Age"].astype("int32")

# %%
df2
# Out:
#     Name  Age        City Gender            Emial   Join Date
# 0  Alice   25    New York      F  alice@gmail.com  01-05-2021
# 1    Bob   30  Los Angels      M    bob@gmial.com  15-06-2020
# 3  David   22      Mumbai      M  david@gmail.com  12-11-2019
# 5  Alice   25    New York      F  alice@gmail.com  01-05-2021
# 6  Alice   25    New York      F  alice@gmail.com  01-05-2021

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int32
#  2   City       5 non-null      object
#  3   Gender     5 non-null      object
#  4   Emial      5 non-null      object
#  5   Join Date  5 non-null      object
# dtypes: int32(1), object(5)
# memory usage: 260.0+ bytes

# %%
df2.dtypes
# Out:
# Name         object
# Age           int32
# City         object
# Gender       object
# Emial        object
# Join Date    object
# dtype: object

# %%
df2
# Out:
#     Name  Age        City Gender            Emial   Join Date
# 0  Alice   25    New York      F  alice@gmail.com  01-05-2021
# 1    Bob   30  Los Angels      M    bob@gmial.com  15-06-2020
# 3  David   22      Mumbai      M  david@gmail.com  12-11-2019
# 5  Alice   25    New York      F  alice@gmail.com  01-05-2021
# 6  Alice   25    New York      F  alice@gmail.com  01-05-2021

# %%
df2["Age Group"] = df2["Age"].apply(lambda x: "Adult" if x >= 25 else "Minnor")

# %%
df2
# Out:
#     Name  Age        City Gender            Emial   Join Date Age Group
# 0  Alice   25    New York      F  alice@gmail.com  01-05-2021     Adult
# 1    Bob   30  Los Angels      M    bob@gmial.com  15-06-2020     Adult
# 3  David   22      Mumbai      M  david@gmail.com  12-11-2019    Minnor
# 5  Alice   25    New York      F  alice@gmail.com  01-05-2021     Adult
# 6  Alice   25    New York      F  alice@gmail.com  01-05-2021     Adult

# %%
def isminnor(x):
    return "Adult" if x >= 25 else "Minnor"
df2["Age Group"] = df2["Age"].apply(isminnor)

# %%
df2
# Out:
#     Name  Age        City Gender            Emial   Join Date Age Group
# 0  Alice   25    New York      F  alice@gmail.com  01-05-2021     Adult
# 1    Bob   30  Los Angels      M    bob@gmial.com  15-06-2020     Adult
# 3  David   22      Mumbai      M  david@gmail.com  12-11-2019    Minnor
# 5  Alice   25    New York      F  alice@gmail.com  01-05-2021     Adult
# 6  Alice   25    New York      F  alice@gmail.com  01-05-2021     Adult

# %%
gender_map = {"M":"Male","F":"Female","O":"Other"}
df["Gender"] = df["Gender"].map(gender_map)

# %%
df
# Out:
#       Name   Age        City  Gender              Emial   Join Date
# 0    Alice  25.0    New York  Female    alice@gmail.com  01-05-2021
# 1      Bob  30.0  Los Angels    Male      bob@gmial.com  15-06-2020
# 2  Charlie   NaN       Delhi    Male  charlie@gmail.com  20-07-2021
# 3    David  22.0      Mumbai    Male    david@gmail.com  12-11-2019
# 4      NaN  28.0       Delhi  Female      eve@gmail.com         NaN
# 5    Alice  25.0    New York  Female    alice@gmail.com  01-05-2021
# 6    Alice  25.0    New York  Female    alice@gmail.com  01-05-2021
# 7  Charlie   NaN       Delhi    Male  charlie@gmail.com  20-07-2021
# 8  Charlie   NaN       Delhi    Male  charlie@gmail.com  20-07-2021

# %%
df2["City"] = df2["City"].replace({"Delhi":"New Delhi","Mumbai":"New Mumbai"})

# %%
df2
# Out:
#     Name  Age        City  Gender            Emial   Join Date Age Group
# 0  Alice   25    New York  Female  alice@gmail.com  01-05-2021     Adult
# 1    Bob   30  Los Angels    Male    bob@gmial.com  15-06-2020     Adult
# 3  David   22  New Mumbai    Male  david@gmail.com  12-11-2019    Minnor
# 5  Alice   25    New York  Female  alice@gmail.com  01-05-2021     Adult
# 6  Alice   25    New York  Female  alice@gmail.com  01-05-2021     Adult
